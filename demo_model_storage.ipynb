# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

km = KMeans(n_clusters=2, random_state=0)
y_km = km.fit_predict(X)
plt.scatter(X[y_km==0,0], X[y_km==0,1], c='red', marker='o', s=40, label='cluster 1')
plt.scatter(X[y_km==1,0], X[y_km==1,1], c='lightblue', marker='s', s=40, label='cluster 2')
plt.title('K-means clustering')

plt.legend()
plt.show()

# %%
from mysql_model import sql4cluster
model_storage = sql4cluster(model_name='Kmeans')

# %%
model_storage.save_model_to_pkl(km)
pkl_model = model_storage.load_model_from_pkl()

# %%
y_pkl = pkl_model.fit_predict(X)
plt.scatter(X[y_pkl==0,0], X[y_pkl==0,1], c='red', marker='o', s=40, label='cluster 1')
plt.scatter(X[y_pkl==1,0], X[y_pkl==1,1], c='lightblue', marker='s', s=40, label='cluster 2')
plt.title('K-means clustering')

plt.legend()
plt.show()
